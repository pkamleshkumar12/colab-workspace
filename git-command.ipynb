# %% [markdown]
# # Mounting gdrive
#
# ```
# from google.colab import drive
# drive.mount('/content/gdrive')
# %cd /content/gdrive/My Drive/colab-workspace
# !pwd
# ```

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd /content/gdrive/My Drive/colab-workspace/colab-workspace
# Out:
# /content/gdrive/My Drive/colab-workspace/colab-workspace

# %%
# !pwd
# Out:
# /content/gdrive/My Drive/colab-workspace/colab-workspace

# %% [markdown]
# # Initiating new repo and user config

# %%
# !git init

# %%
# !git remote remove origin

# %%
# !git remote add origin git@github.com:pkamleshkumar12/colab-workspace.git

# %%
# !git remote -v

# %%
# !git config --global user.email "pkamleshkumar12@gmail.com"
# !git config --global user.name "Kamlesh"

# %%
# !git add .
# !git commit -m "message"

# %%
# !git push -u origin master

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f90ea8f9-13b1-434a-a731-9514ebdd37b0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f90ea8f9-13b1-434a-a731-9514ebdd37b0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Capture.PNG to Capture.PNG

# %% [markdown]
# # Adding ssh-key
#
# #### To upload ssh private key to gdrive
# ```
# from google.colab import files
# uploaded = files.upload()
# ```
#
# #### directory structure
# ```
# .
# ├── git-command.ipynb
# └── ssh-colab
#     ├── config
#     ├── id_ed25519
#     └── id_ed25519.pub
# ```
#
# #### config file content
#
# ```
# # colab account
# Host github.com
#         HostName github.com
#         User git
#         IdentityFile /root/.ssh/id_ed25519
# ```

# %%
# !ls
# Out:
# git-command.ipynb  id_ed25519

# %%
# !apt-get install tree
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 37 not upgraded.
# Need to get 40.7 kB of archives.
# After this operation, 105 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tree amd64 1.7.0-5 [40.7 kB]
# Fetched 40.7 kB in 0s (608 kB/s)
# Selecting previously unselected package tree.
# (Reading database ... 155222 files and directories currently installed.)
# Preparing to unpack .../tree_1.7.0-5_amd64.deb ...
# Unpacking tree (1.7.0-5) ...
# Setting up tree (1.7.0-5) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
# !tree
# Out:
# .
# ├── git-command.ipynb
# └── ssh-colab
#     ├── config
#     ├── id_ed25519
#     └── id_ed25519.pub
#
# 1 directory, 4 files

# %%
# Remove the ssh folder and its contents if already present
# !rm -rf /root/.ssh

# %%
# Create a new .ssh folder
# !mkdir /root/.ssh

# %%
# Copy the private, public keys and config files into the /root/.ssh folder
# !cp ssh-colab/* /root/.ssh

# %%
# !ls -a /root/.ssh
# Out:
# .  ..  config  id_ed25519  id_ed25519.pub

# %%
# Add the git server as a ssh known host
# !touch /root/.ssh/known_hosts
# !ssh-keyscan github.com >> /root/.ssh/known_hosts
# !chmod 644 /root/.ssh/known_hosts
# Out:
# # github.com:22 SSH-2.0-babeld-17a926d7
# # github.com:22 SSH-2.0-babeld-17a926d7
# # github.com:22 SSH-2.0-babeld-17a926d7

# %%
# !ssh git@gitlab.com
# Out:
# Host key verification failed.

# %%
# !cat ~/.ssh/config
# Out:
# # colab account
# Host github.com
# 	HostName github.com
# 	User git
# 	IdentityFile /root/.ssh/id_ed25519

# %%
# !git clone git@github.com:pkamleshkumar12/colab-workspace.git
# Out:
# Cloning into 'colab-workspace'...
# ...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# Receiving objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0

# %% [markdown]
# # Git add and Commit

# %%
!
